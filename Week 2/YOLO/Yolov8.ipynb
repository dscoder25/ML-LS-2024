# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.2/800.2 kB 8.8 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
from ultralytics import YOLO

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/car
# Out:
# /content/drive/MyDrive/car

# %%
# !ls
# Out:
# data.yaml	    README.roboflow.txt  test	valid	    yolov8s.pt
# README.dataset.txt  runs		 train	yolov8n.pt

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=data.yaml epochs=100 imgsz=640 plots=True
# Out:
# Ultralytics YOLOv8.2.55 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=val model='/content/drive/MyDrive/car/runs/detect/train6/weights/best.pt' data=data.yaml
# Out:
# Ultralytics YOLOv8.2.55 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,131,776 parameters, 0 gradients, 28.5 GFLOPs
# val: Scanning /content/drive/MyDrive/car/valid/labels.cache... 160 images, 1 backgrounds, 0 corrupt: 100% 160/160 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 10/10 [00:09<00:00,  1.10it/s]
#                    all        160       1055       0.74      0.682      0.731      0.546
#                   boot         35         39      0.601      0.513      0.617      0.488
#                    car        142        145       0.91      0.966      0.944      0.847
#                   door         50         52      0.881      0.885      0.933      0.676
#           front_bumper         30         30      0.566        0.5      0.596      0.477
#            front_grill         49         51       0.71      0.588       0.57      0.474
# ...

# %%
# !yolo task=detect mode=predict model='/content/drive/MyDrive/car/runs/detect/train6/weights/best.pt' conf=0.25 source='/content/drive/MyDrive/car/test/images'
# Out:
# Ultralytics YOLOv8.2.55 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,131,776 parameters, 0 gradients, 28.5 GFLOPs
#
# image 1/22 /content/drive/MyDrive/car/test/images/Cars212_png.rf.c31b66dbfb5e4d5bc2e10f4b331f03aa.jpg: 640x640 1 car, 1 front_grill, 1 headlamp, 1 license_plate, 17.7ms
# image 2/22 /content/drive/MyDrive/car/test/images/Cars260_png.rf.358fc27422dbe6062fced88e7e5b59cc.jpg: 640x640 2 cars, 1 license_plate, 16.4ms
# image 3/22 /content/drive/MyDrive/car/test/images/Cars295_png.rf.5452c67121f3be7c3e37148a9cc4936d.jpg: 640x640 2 cars, 2 license_plates, 16.3ms
# image 4/22 /content/drive/MyDrive/car/test/images/Cars304_png.rf.f31408152fe09e73a74c2949a65058a0.jpg: 640x640 1 car, 1 front_grill, 1 headlamp, 1 license_plate, 1 wheel, 16.3ms
# ...
